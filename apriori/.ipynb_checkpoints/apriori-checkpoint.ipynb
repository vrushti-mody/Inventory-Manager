# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header = None)

# %%
#Gives you information about the dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20027 entries, 0 to 20026
# Data columns (total 20 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       20027 non-null  object
#  1   1       18273 non-null  object
#  2   2       15513 non-null  object
#  3   3       12877 non-null  object
#  4   4       10395 non-null  object
#  5   5       7783 non-null   object
#  6   6       5163 non-null   object
#  7   7       2777 non-null   object
#  8   8       1184 non-null   object
#  9   9       487 non-null    object
#  10  10      264 non-null    object
#  11  11      154 non-null    object
#  12  12      87 non-null     object
#  13  13      47 non-null     object
#  14  14      25 non-null     object
#  15  15      8 non-null      object
#  16  16      4 non-null      object
#  17  17      4 non-null      object
#  18  18      3 non-null      object
#  19  19      1 non-null      object
# dtypes: object(20)
# memory usage: 3.1+ MB

# %%
#To display first 5 rows present in the dataset
dataset.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# 0  low fat yogurt  green tea  honey  salad  mineral water  salmon
# 1             NaN        NaN    NaN    NaN            NaN     NaN
# 2             NaN        NaN    NaN    NaN            NaN     NaN
# 3             NaN        NaN    NaN    NaN            NaN     NaN
# 4             NaN        NaN    NaN    NaN            NaN     NaN
#
#                   16               17       18         19
# 0  antioxydant juice  frozen smoothie  spinach  olive oil
# 1                NaN              NaN      NaN        NaN
# 2                NaN              NaN      NaN        NaN
# 3                NaN              NaN      NaN        NaN
# 4                NaN              NaN      NaN        NaN

# %%
#To check for duplicates
dataset.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20022    False
# 20023    False
# 20024    False
# 20025    False
# 20026     True
# Length: 20027, dtype: bool

# %%
#To delete duplicates
dataset.drop_duplicates(subset=None, inplace=True)

# %%
transactions = []
for i in range(0, len(dataset)):
    transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])

# %%
from apyori import apriori

# %%
rules = apriori(transactions, min_support = 0.00175, min_confidence = 0.5, min_lift = 2, min_length = 2)

# %%
results = list(rules)
print(results)
# Out:
# [RelationRecord(items=frozenset({'nonfat milk', 'mineral water'}), support=0.0024282701770081154, ordered_statistics=[OrderedStatistic(items_base=frozenset({'nonfat milk'}), items_add=frozenset({'mineral water'}), confidence=0.5205479452054794, lift=5.248746645953961)]), RelationRecord(items=frozenset({'chocolate', 'chicken', 'mineral water'}), support=0.0036424052655121735, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate', 'chicken'}), items_add=frozenset({'mineral water'}), confidence=0.5181818181818182, lift=5.224888706654171)]), RelationRecord(items=frozenset({'chicken', 'spaghetti', 'ground beef'}), support=0.0023004664834813727, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken', 'ground beef'}), items_add=frozenset({'spaghetti'}), confidence=0.5070422535211269, lift=6.679043960734103)]), RelationRecord(items=frozenset({'pancakes', 'chicken', 'mineral water'}), support=0.0023004664834813727, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pancakes', 'chicken'}), items_add=frozenset({'mineral water'}), confidence=0.5373134328358209, lift=5.417795045391599)]), RelationRecord(items=frozenset({'chocolate', 'mineral water', 'olive oil'}), support=0.003961914499329031, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate', 'olive oil'}), items_add=frozenset({'mineral water'}), confidence=0.5081967213114754, lift=5.12420779111036)]), RelationRecord(items=frozenset({'chocolate', 'mineral water', 'soup'}), support=0.0026838775640616016, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chocolate', 'soup'}), items_add=frozenset({'mineral water'}), confidence=0.56, lift=5.646546391752578)]), RelationRecord(items=frozenset({'cooking oil', 'eggs', 'mineral water'}), support=0.00306728864464183, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cooking oil', 'eggs'}), items_add=frozenset({'mineral water'}), confidence=0.5454545454545454, lift=5.499882849109652)]), RelationRecord(items=frozenset({'cooking oil', 'spaghetti', 'ground beef'}), support=0.0023004664834813727, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cooking oil', 'ground beef'}), items_add=frozenset({'spaghetti'}), confidence=0.5714285714285715, lift=7.527176527176528)]), RelationRecord(items=frozenset({'cooking oil', 'pancakes', 'mineral water'}), support=0.002236564636718001, ordered_statistics=[OrderedStatistic(items_base=frozenset({'cooking oil', 'pancakes'}), items_add=frozenset({'mineral water'}), confidence=0.5932203389830508, lift=5.981511008212475)]), RelationRecord(items=frozenset({'mineral water', 'eggs', 'ground beef'}), support=0.00479263850725286, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'ground beef'}), items_add=frozenset({'mineral water'}), confidence=0.5033557046979865, lift=5.075395246661592)]), RelationRecord(items=frozenset({'eggs', 'mineral water', 'soup'}), support=0.0023643683302447442, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'soup'}), items_add=frozenset({'mineral water'}), confidence=0.5522388059701493, lift=5.568289352208033)]), RelationRecord(items=frozenset({'spaghetti', 'eggs', 'red wine'}), support=0.001789251709374401, ordered_statistics=[OrderedStatistic(items_base=frozenset({'eggs', 'red wine'}), items_add=frozenset({'spaghetti'}), confidence=0.5283018867924528, lift=6.959087732672638)]), RelationRecord(items=frozenset({'milk', 'escalope', 'mineral water'}), support=0.0019170554029011438, ordered_statistics=[OrderedStatistic(items_base=frozenset({'milk', 'escalope'}), items_add=frozenset({'mineral water'}), confidence=0.5172413793103449, lift=5.215406150017775)]), RelationRecord(items=frozenset({'mineral water', 'ground beef', 'frozen vegetables'}), support=0.004409227426672631, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ground beef', 'frozen vegetables'}), items_add=frozenset({'mineral water'}), confidence=0.5433070866141733, lift=5.478229767026544)]), RelationReco ...

# %%
df = pd.DataFrame(results)

# %%
df.to_csv(r'Output.csv', index = False)

# %%
df
# Out:
#                                                 items   support  \
# 0                        (nonfat milk, mineral water)  0.002428
# 1                 (chocolate, chicken, mineral water)  0.003642
# 2                   (chicken, spaghetti, ground beef)  0.002300
# 3                  (pancakes, chicken, mineral water)  0.002300
# 4               (chocolate, mineral water, olive oil)  0.003962
# ..                                                ...       ...
# 89  (mineral water, ground beef, nan, milk, frozen...  0.001789
# 90  (mineral water, ground beef, nan, spaghetti, f...  0.002109
# 91  (mineral water, nan, milk, spaghetti, frozen v...  0.002173
# 92  (Milk, Coffee Powder, Bread, Sugar, Lassi, Pan...  0.002237
# 93  (Milk, Coffee Powder, Bread, Sugar, Lassi, Pan...  0.002237
#
#                                    ordered_statistics
# 0   [((nonfat milk), (mineral water), 0.5205479452...
# 1   [((chocolate, chicken), (mineral water), 0.518...
# 2   [((chicken, ground beef), (spaghetti), 0.50704...
# 3   [((pancakes, chicken), (mineral water), 0.5373...
# 4   [((chocolate, olive oil), (mineral water), 0.5...
# ..                                                ...
# 89  [((milk, nan, ground beef, frozen vegetables),...
# 90  [((nan, spaghetti, ground beef, frozen vegetab...
# 91  [((milk, nan, spaghetti, frozen vegetables), (...
# 92  [((Milk, Coffee Powder, Bread, Sugar, Panner, ...
# 93  [((Milk, Coffee Powder, Bread, Sugar, Panner, ...
#
# [94 rows x 3 columns]
